# %% [markdown]
# ### Invoking Sagemaker from a Docker container.
# This script is based on a modified version of this example:
# https://github.com/awslabs/amazon-sagemaker-examples/blob/master/introduction_to_amazon_algorithms/random_cut_forest/random_cut_forest.ipynb
#
# Where it differs is in the two examples presented and the need to use credentials imported to the container
#
# ## Version with flattened sinewave

# %%
import boto3
import sagemaker
import numpy as np
from sagemaker.predictor import csv_serializer, json_deserializer
from sagemaker import RandomCutForest

# %%
bucket = 'dbgsagemaker'   # <--- specify a bucket you have access to
prefix = 'sagemaker/rcf-benchmarks'

# %%
import os
os.environ['AWS_DEFAULT_REGION'] = 'us-east-2'
os.environ['AWS_DEFAULT_PROFILE']= 'ec2-user'

# %%
import pandas as pd
import urllib.request

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.dpi'] = 100

# %%
#insert your sagemaker execution role below
iam = boto3.client('iam', region_name='us-east-2') 
role = iam.get_role(RoleName='AmazonSageMaker-ExecutionRole-<your role here')['Role']['Arn']

# %%
def shingle(data, shingle_size):
    num_data = len(data)
    shingled_data = np.zeros((num_data-shingle_size, shingle_size))
    
    for n in range(num_data - shingle_size):
        shingled_data[n] = data[n:(n+shingle_size)]
    return shingled_data

# %% [markdown]
# ### Now fetch weather station data for skagit valley

# %%
data_filename = 'skajit.csv'
data_source = 'https://dbgsagemaker.s3.us-east-2.amazonaws.com/skajit.csv'
urllib.request.urlretrieve(data_source, data_filename)
skajit = pd.read_csv(data_filename, delimiter=',')

# %%
skajit.values[:,0]
# Out:
# array([37.4, 37.4, 39.2, 46.4, 51.8, 55.4, 46.4, 46.4, 46.4, 44.6, 46.4,
#        48.2, 44.6, 46.4, 51.8, 53.6, 51.8, 55.4, 51.8, 48.2, 44.6, 50.0,
#        55.4, 57.2, 57.2, 66.2, 60.8, 53.6, 51.8, 51.8, 48.2, 48.2, 48.2,
#        48.2, 50.0, 57.2, 59.0, 57.2, 60.8, 57.2, 55.4, 57.2, 55.4, 57.2,
#        55.4, 51.8, 57.2, 53.6, 55.4, 55.4, 51.8, 57.2, 57.2, 53.6, 53.6,
#        51.8, 51.8, 51.8, 55.4, 51.8, 50.0, 48.2, 51.8, 53.6, 53.6, 55.4,
#        57.2, 55.4, 51.8, 53.6, 53.6, 53.6, 53.6, 53.6, 53.6, 53.6, 53.6,
#        53.6, 53.6, 60.8, 60.8, 60.8, 60.8, 60.8, 60.8, 66.2, 64.4, 60.8,
#        64.4, 62.6, 53.6, 55.4, 53.6, 55.4, 57.2, 55.4, 57.2, 60.8, 62.6,
#        60.8, 51.8, 55.4, 53.6, 53.6, 55.4, 60.8, 62.6, 59.0, 62.6, 68.0,
#        68.0, 55.4, 55.4, 55.4, 53.6, 59.0, 68.0, 68.0, 62.6, 60.8, 60.8,
#        59.0, 62.6, 62.6, 60.8, 59.0, 64.4, 68.0, 73.4, 73.4, 62.6, 64.4,
#        60.8, 62.6, 64.4, 64.4, 66.2, 69.8, 69.8, 69.8, 73.4, 71.6, 62.6,
#        60.8, 62.6, 68.0, 71.6, 75.2, 73.4, 71.6, 69.8, 66.2, 60.8, 62.6,
#        68.0, 73.4, 75.2, 78.8, 80.6, 77.0, 75.2, 75.2, 68.0, 68.0, 73.4,
#        78.8, 75.2, 69.8, 69.8, 68.0, 71.6, 73.4, 75.2, 73.4, 75.2, 82.4,
#        80.6, 84.2, 84.2, 82.4, 82.4, 80.6, 84.2, 84.2, 82.4, 82.4, 78.8,
#        75.2, 78.8, 77.0, 77.0, 69.8, 78.8, 77.0, 77.0, 77.0, 75.2, 77.0,
#        84.2, 91.4, 91.4, 73.4, 71.6, 73.4, 71.6, 68.0, 68.0, 73.4, 77.0,
#        86.0, 86.0, 86.0, 84.2, 82.4, 82.4, 77.0, 73.4, 75.2, 78.8, 77.0,
#        77.0, 77.0, 78.8, 80.6, 78.8, 78.8, 69.8, 73.4, 75.2, 78.8, 86.0,
#        82.4, 73.4, 75.2, 78.8, 75.2, 75.2, 77.0, 80.6, 78.8, 71.6, 71.6,
#        68.0, 62.6, 66.2, 60.8, 62.6, 68.0, 68.0, 69.8, 68.0, 73.4, 73.4,
#        73.4, 73.4, 73.4, 62.6, 64.4, 82.4, 107.6, 108.0, 108.0, 108.0,
#        108.0, 108.0, 108.0, 111.2, 111.2, 60.8, 60.8, 62.6, 66.2, 68.0,
#        66.2, 64.4, 69.8, 66.2, 66.2, 64.4, 62.6, 64.4, 69.8, 68.0, 64.4,
#        60.8, 59.0, 57.2, 64.4, 66.2, 62.6, 60.8, 64.4, 60.8, 57.2, 57.2,
#        55.4, 53.6, 66.2, 57.2, 60.8, 55.4, 60.8, 62.6, 59.0, 55.4, 53.6,
#        51.8, 50.0, 51.8, 55.4, 59.0, 53.6, 50.0, 50.0, 51.8, 50.0, 55.4,
#        50.0, 44.6, 46.4, 55.4, 50.0, 44.6, 44.6, 44.6, 44.6, 41.0, 46.4,
#        44.6, 44.6, 42.8, 42.8, 41.0, 39.2, 55.4, 51.8, 60.8, 55.4, 51.8,
#        53.6, 53.6, 59.0, 53.6, 51.8, 50.0, 44.6, 48.2, 44.6, 42.8, 39.2,
#        39.2, 44.6, 46.4, 46.4, 42.8, 41.0, 41.0, 39.2, 41.0, 39.2, 41.0,
#        41.0, 41.0, 37.4, 32.0], dtype=object)

# %%
# single data with shingle size=48 (one day)
shingle_size = 48
prefix_shingled = 'sagemaker/randomcutforest_shingled'
skajit_data_shingled = shingle(skajit.values[:,0], shingle_size)
print(skajit_data_shingled)
# Out:
# [[37.4 37.4 39.2 ... 51.8 57.2 53.6]
#  [37.4 39.2 46.4 ... 57.2 53.6 55.4]
#  [39.2 46.4 51.8 ... 53.6 55.4 55.4]
#  ...
#  [51.8 50.  55.4 ... 39.2 41.  41. ]
#  [50.  55.4 50.  ... 41.  41.  41. ]
#  [55.4 50.  44.6 ... 41.  41.  37.4]]

# %%
session = sagemaker.Session()

# specify general training job information
rcf = RandomCutForest(role=role,
                      train_instance_count=1,
                      train_instance_type='ml.m4.xlarge',
                      data_location='s3://{}/{}/'.format(bucket, prefix_shingled),
                      output_path='s3://{}/{}/output'.format(bucket, prefix_shingled),
                      num_samples_per_tree=512,
                      num_trees=50)

# automatically upload the training data to S3 and run the training job
rcf.fit(rcf.record_set(skajit_data_shingled))
# Out:
# 2020-03-11 18:29:29 Starting - Starting the training job...
# 2020-03-11 18:29:31 Starting - Launching requested ML instances...
# 2020-03-11 18:30:29 Starting - Preparing the instances for training......
# 2020-03-11 18:31:18 Downloading - Downloading input data...
# 2020-03-11 18:31:41 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# /opt/amazon/lib/python2.7/site-packages/scipy/_lib/_numpy_compat.py:10: DeprecationWarning: Importing from numpy.testing.nosetester is deprecated, import from numpy.testing instead.
#   from numpy.testing.nosetester import import_nose
# /opt/amazon/lib/python2.7/site-packages/scipy/stats/morestats.py:12: DeprecationWarning: Importing from numpy.testing.decorators is deprecated, import from numpy.testing instead.
#   from numpy.testing.decorators import setastest
# [03/11/2020 18:32:18 INFO 139712752109376] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'_ftp_port': 8999, u'num_samples_per_tree': 256, u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'_log_level': u'info', u'_kvstore': u'dist_async', u'force_dense': u'true', u'epochs': 1, u'num_trees': 100, u'eval_metrics': [u'accuracy', u'precision_recall_fscore'], u'_num_kv_servers': u'auto', u'mini_batch_size': 1000}
# [03/11/2020 18:32:18 INFO 139712752109376] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'mini_batch_size': u'1000', u'feature_dim': u'48', u'num_samples_per_tree': u'512', u'num_trees': u'50'}
# [03/11/2020 18:32:18 INFO 139712752109376] Final configuration: {u'_ftp_port': 8999, u'num_samples_per_tree': u'512', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'_log_level': u'info', u'_kvstore': u'dist_async', u'force_dense': u'true', u'epochs': 1, u'feature_dim': u'48', u'num_trees': u'50', u'eval_metrics': [u'accuracy', u'precision_recall_fscore'], u'_num_kv_servers': u'auto', u'mini_batch_size': u'1000'}
# [03/11/2020 18:32:18 WARNING 139712752109376] Loggers have already been setup.
# [03/11/2020 18:32:18 INFO 139712752109376] Launching parameter server for role scheduler
# [03/11/2020 18:32:18 INFO 139712752109376] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/03b4f3c4-84ec-47a2-b24f-cfd4451db78a', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-2', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'randomcutforest-2020-03-11-18-29-29-753', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-161-61.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/3bf5d0f9-4a65-4ab3-8190-96297f83e6ab', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:066301190734:training-job/randomcutforest-2020-03-11-18-29-29-753', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [03/11/2020 18:32:18 INFO 139712752109376] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/03b4f3c4-84ec-47a2-b24f-cfd4451db78a', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.161.61', 'AWS_REGION': 'us-east-2', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'randomcutforest-2020-03-11-18-29-29-753', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-161-61.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/3bf5d0f9-4a65-4ab3-8190-96297f83e6ab', 'DMLC_ROLE': 'scheduler', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:066301190734:training-job/randomcutforest-2020-03-11-18-29-29-753', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [03/11/2020 18:32:18 INFO 139712752109376] Launching parameter server for role server
# [03/11/2020 18:32:18 INFO 139712752109376] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/03b4f3c4-84ec-47a2-b24f-cfd4451db78a', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-2', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'randomcutforest-2020-03-11-18-29-29-753', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-161-61.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/3bf5d0f9-4a65-4ab3-8190-96297f83e6ab', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:066301190734:training-job/randomcutforest-2020-03-11-18-29-29-753', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [03/11/2020 18:32:18 INFO 139712752109376] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/03b4f3c4-84ec-47a2-b24f-cfd4451db78a', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.161.61', 'AWS_REGION': 'us-east-2', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'randomcutforest-2020-03-11-18-29-29-753', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-161-61.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/3bf5d0f9-4a65-4ab3-8190-96297f83e6ab', 'DMLC_ROLE': 'server', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:066301190734:training-job/randomcutforest-2020-03-11-18-29-29-753', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [03/11/2020 18:32:18 INFO 139712752109376] Environment: {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/03b4f3c4-84ec-47a2-b24f-cfd4451db78a', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '1', 'SAGEMAKER_HTTP_PORT': '8080', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.161.61', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'randomcutforest-2020-03-11-18-29-29-753', 'HOME': '/root', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-161-61.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/3bf5d0f9-4a65-4ab3-8190-96297f83e6ab', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:066301190734:training-job/randomcutforest-2020-03-11-18-29-29-753', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# Process 31 is a shell:scheduler.
# Process 32 is a shell:server.
# Process 1 is a worker.
# [03/11/2020 18:32:18 INFO 139712752109376] Using default worker.
# [03/11/2020 18:32:18 INFO 139712752109376] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [03/11/2020 18:32:18 INFO 139712752109376] Verifying hyperparamemters...
# [03/11/2020 18:32:18 INFO 139712752109376] Hyperparameters are correct.
# [03/11/2020 18:32:18 INFO 139712752109376] Validating that feature_dim agrees with dimensions in training data...
# [03/11/2020 18:32:18 INFO 139712752109376] feature_dim is correct.
# [03/11/2020 18:32:18 INFO 139712752109376] Validating memory limits...
# [03/11/2020 18:32:18 INFO 139712752109376] Available memory in bytes: 15314833408
# [03/11/2020 18:32:18 INFO 139712752109376] Estimated sample size in bytes: 19660800
# [03/11/2020 18:32:18 INFO 139712752109376] Estimated memory needed to build the forest in bytes: 49152000
# [03/11/2020 18:32:18 INFO 139712752109376] Memory limits validated.
# [03/11/2020 18:32:18 INFO 139712752109376] Starting cluster sharing facilities...
# [I 20-03-11 18:32:18] >>> starting FTP server on 0.0.0.0:8999, pid=1 <<<
# [03/11/2020 18:32:18 INFO 139712752109376] Create Store: dist_async
# [03/11/2020 18:32:18 INFO 139711348725504] >>> starting FTP server on 0.0.0.0:8999, pid=1 <<<
# [I 20-03-11 18:32:18] poller: <class 'pyftpdlib.ioloop.Epoll'>
# [03/11/2020 18:32:18 INFO 139711348725504] poller: <class 'pyftpdlib.ioloop.Epoll'>
# [03/11/2020 18:32:18 INFO 139711348725504] masquerade (NAT) address: None
# [I 20-03-11 18:32:18] masquerade (NAT) address: None
# [03/11/2020 18:32:18 INFO 139711348725504] passive ports: None
# [I 20-03-11 18:32:18] passive ports: None
# [I 20-03-11 18:32:18] use sendfile(2): False
# [03/11/2020 18:32:18 INFO 139711348725504] use sendfile(2): False
# [03/11/2020 18:32:18 INFO 139712752109376] Cluster sharing facilities started.
# [03/11/2020 18:32:18 INFO 139712752109376] Verifying all workers are accessible...
# [03/11/2020 18:32:18 INFO 139712752109376] All workers accessible.
# [03/11/2020 18:32:18 INFO 139712752109376] Initializing Sampler...
# [03/11/2020 18:32:18 INFO 139712752109376] Sampler correctly initialized.
# #metrics {"Metrics": {"initialize.time": {"count": 1, "max": 811.2859725952148, "sum": 811.2859725952148, "min": 811.2859725952148}}, "EndTime": 1583951538.84685, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "RandomCutForest"}, "StartTime": 1583951538.031866}
#
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1583951538.847313, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "RandomCutForest"}, "StartTime": 1583951538.847026}
#
# [2020-03-11 18:32:18.847] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 814, "num_examples": 1, "num_bytes": 130604}
# [03/11/2020 18:32:18 INFO 139712752109376] Sampling training data...
# [2020-03-11 18:32:18.862] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 14, "num_examples": 1, "num_bytes": 130604}
# [03/11/2020 18:32:18 INFO 139712752109376] Sampling training data completed.
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "update.time": {"count": 1, "max": 18.849849700927734, "sum": 18.849849700927734, "min": 18.849849700927734}}, "EndTime": 1583951538.866441, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "RandomCutForest"}, "StartTime": 1583951538.846956}
#
# [03/11/2020 18:32:18 INFO 139712752109376] Early stop condition met. Stopping training.
# [03/11/2020 18:32:18 INFO 139712752109376] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 317, "sum": 317.0, "min": 317}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 317, "sum": 317.0, "min": 317}, "Max Records Seen Between Resets": {"count": 1, "max": 317, "sum": 317.0, "min": 317}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1583951538.866815, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "RandomCutForest", "epoch": 0}, "StartTime": 1583951538.847558}
#
# [03/11/2020 18:32:18 INFO 139712752109376] #throughput_metric: host=algo-1, train throughput=16337.6959033 records/second
# [03/11/2020 18:32:18 INFO 139712752109376] Master node: building Random Cut Forest...
# [03/11/2020 18:32:18 INFO 139712752109376] Gathering samples...
# [03/11/2020 18:32:18 INFO 139712752109376] 317 samples gathered
# [03/11/2020 18:32:18 INFO 139712752109376] Building Random Cut Forest...
# [03/11/2020 18:32:18 INFO 139712752109376] Random Cut Forest built:
#
# ForestInfo{num_trees: 50, num_samples_in_forest: 300, num_samples_per_tree: 6, sample_dim: 48, shingle_size: 1, trees_num_nodes: [11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, ], trees_depth: [5, 5, 5, 5, 5, 5, 5, 4, 6, 6, 5, 4, 5, 4, 5, 4, 5, 5, 4, 4, 6, 5, 5, 4, 6, 5, 4, 4, 4, 5, 6, 4, 4, 5, 6, 6, 5, 5, 5, 6, 5, 4, 4, 6, 4, 5, 4, 4, 4, 6, ], max_num_nodes: 11, min_num_nodes: 11, avg_num_nodes: 11, max_tree_depth: 6, min_tree_depth: 4, avg_tree_depth: 4, mem_size: 471248}
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 2.5451183319091797, "sum": 2.5451183319091797, "min": 2.5451183319091797}, "model.bytes": {"count": 1, "max": 471248, "sum": 471248.0, "min": 471248}, "fit_model.time": {"count": 1, "max": 1.1370182037353516, "sum": 1.1370182037353516, "min": 1.1370182037353516}}, "EndTime": 1583951538.869663, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "RandomCutForest"}, "StartTime": 1583951538.866534}
#
# [03/11/2020 18:32:18 INFO 139712752109376] Master node: Serializing the RandomCutForest model
# #metrics {"Metrics": {"serialize_model.time": {"count": 1, "max": 8.168935775756836, "sum": 8.168935775756836, "min": 8.168935775756836}}, "EndTime": 1583951538.877974, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "RandomCutForest"}, "StartTime": 1583951538.869758}
#
# [03/11/2020 18:32:18 INFO 139712752109376] Test data is not provided.
# [03/11/2020 18:32:18 INFO 139711348725504] >>> shutting down FTP server (0 active fds) <<<
# [I 20-03-11 18:32:18] >>> shutting down FTP server (0 active fds) <<<
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 1110.7091903686523, "sum": 1110.7091903686523, "min": 1110.7091903686523}, "setuptime": {"count": 1, "max": 192.8119659423828, "sum": 192.8119659423828, "min": 192.8119659423828}}, "EndTime": 1583951538.942549, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "RandomCutForest"}, "StartTime": 1583951538.87828}
#
#
# 2020-03-11 18:32:26 Uploading - Uploading generated training model
# 2020-03-11 18:32:26 Completed - Training job completed
# Training seconds: 68
# Billable seconds: 68

# %%
rcf_inference = rcf.deploy(
    initial_instance_count=1,
    instance_type='ml.m4.xlarge',
)

rcf_inference.content_type = 'text/csv'
rcf_inference.serializer = csv_serializer
rcf_inference.accept = 'appliation/json'
rcf_inference.deserializer = json_deserializer
# Out:
# -----------!

# %%
# Score the shingled datapoints
results = rcf_inference.predict(skajit_data_shingled)
scores = np.array([datum['score'] for datum in results['scores']])

# compute the shingled score distribution and cutoff and determine anomalous scores
score_mean = scores.mean()
score_std = scores.std()
score_cutoff = score_mean + 1.8*score_std

anomalies = scores[scores > score_cutoff]
anomaly_indices = np.arange(len(scores))[scores > score_cutoff]

print(anomalies)
# Out:
# [1.94528759 1.93279179 1.93151013 1.93882509 1.9340914  1.93398558
#  1.93515626 1.92487787 1.925311   1.93056333 1.9281298  1.92919984
#  1.92735889 1.92606388 1.92813661 1.92502701 1.93540586 1.93846203
#  1.94422591 1.95343267 1.95917518]

# %%
len(skajit_data_shingled[:,1])
skajit_window = skajit_data_shingled[:,1]

# %%
skajit
# Out:
#      temperature        timestamp
# 0           37.4    1/1/2015 0:00
# 1           37.4    1/2/2015 0:00
# 2           39.2    1/3/2015 0:00
# 3           46.4    1/4/2015 0:00
# 4           51.8    1/5/2015 0:00
# ..           ...              ...
# 360         41.0  12/27/2015 0:00
# 361         41.0  12/28/2015 0:00
# 362         41.0  12/29/2015 0:00
# 363         37.4  12/30/2015 0:00
# 364         32.0  12/31/2015 0:00
#
# [365 rows x 2 columns]

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

#
# *Try this out* - change `start` and `end` to zoom in on the 
# anomaly found earlier in this notebook
#
start, end = 0, len(skajit_window)
skajit_data_subset = skajit_window[start:end]

ax1.plot(skajit_window, color='C0', alpha=0.8)
ax2.plot(scores, color='C1')
ax2.scatter(anomaly_indices, anomalies, color='k')

ax1.grid(which='major', axis='both')
ax1.set_ylabel('temerature', color='C0')
ax2.set_ylabel('Anomaly Score', color='C1')
ax1.tick_params('y', colors='C0')
ax2.tick_params('y', colors='C1')
ax1.set_ylim(0, 150)
ax2.set_ylim(min(scores), 1.4*max(scores))
fig.set_figwidth(10)

# %%
anoms= []
for base in range(100,300):
    results = rcf_inference.predict(skajit_data_shingled[base:base+25])
    scores = np.array([datum['score'] for datum in results['scores']])

    # compute the shingled score distribution and cutoff and determine anomalous scores
    score_mean = scores.mean()
    score_std = scores.std()
    score_cutoff = score_mean +2.4*score_std

    anomalies = scores[scores > score_cutoff]
    anomaly_indices = np.arange(len(scores))[scores > score_cutoff]

    #print(anomalies)
    #print(anomaly_indices+base+10)
    anoms.append(anomaly_indices+base)

# %%
xl = []
for x in anoms:
    xl = xl+x.tolist()
s = set(xl)
xl = list(s)
anomalies = []
for x in xl:
    anomalies.append(2.0)

# %%
xl.sort()

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
anomaly_indices = xl
#
# *Try this out* - change `start` and `end` to zoom in on the 
# anomaly found earlier in this notebook
#
start, end = 0, len(skajit_window)
skajit_data_subset = skajit_window[start:end]

ax1.plot(skajit_window, color='C0', alpha=0.8)
#ax2.plot(scores, color='C1')
ax2.scatter(anomaly_indices, anomalies, color='k')

ax1.grid(which='major', axis='both')
ax1.set_ylabel('temerature', color='C0')
ax2.set_ylabel('Anomaly Score', color='C1')
ax1.tick_params('y', colors='C0')
ax2.tick_params('y', colors='C1')
ax1.set_ylim(0, 150)
ax2.set_ylim(min(scores), 1.4*max(scores))
fig.set_figwidth(10)

# %%
sagemaker.Session().delete_endpoint(rcf_inference.endpoint)

# %% [markdown]
# ### now for fake case.
# in this version we use the sine wave with the flat anomaly

# %%
import numpy as np

# %%
pi = 3.14
fakedata = np.zeros(500)
for i in range(len(fakedata)):
    fakedata[i] = 0.5*np.sin(pi*i/10)+4.0
    pi = 0.9995*pi
for i in range(200,250):
    fakedata[i] = 4.0

# %%
# single data with shingle size=48 (one day)
shingle_size = 48
prefix_shingled = 'sagemaker/randomcutforest_shingled'
fake_data_shingled = shingle(fakedata, shingle_size)
print(fake_data_shingled)
# Out:
# [[4.         4.1543581  4.29350968 ... 4.47436234 4.49988262 4.48080604]
#  [4.1543581  4.29350968 4.40395229 ... 4.49988262 4.48080604 4.41896337]
#  [4.29350968 4.40395229 4.47503964 ... 4.48080604 4.41896337 4.31997455]
#  ...
#  [3.77456149 3.86502435 3.96046141 ... 4.489159   4.46184794 4.41890841]
#  [3.86502435 3.96046141 4.0572742  ... 4.46184794 4.41890841 4.36184736]
#  [3.96046141 4.0572742  4.1518332  ... 4.41890841 4.36184736 4.29263976]]

# %%
session = sagemaker.Session()

# specify general training job information
rcf = RandomCutForest(role=role,
                      train_instance_count=1,
                      train_instance_type='ml.m4.xlarge',
                      data_location='s3://{}/{}/'.format(bucket, prefix_shingled),
                      output_path='s3://{}/{}/output'.format(bucket, prefix_shingled),
                      num_samples_per_tree=512,
                      num_trees=50)

# automatically upload the training data to S3 and run the training job
rcf.fit(rcf.record_set(fake_data_shingled))
# Out:
# 2020-03-15 17:26:47 Starting - Starting the training job...
# 2020-03-15 17:26:48 Starting - Launching requested ML instances...
# 2020-03-15 17:27:43 Starting - Preparing the instances for training......
# 2020-03-15 17:28:39 Downloading - Downloading input data...
# 2020-03-15 17:29:00 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# /opt/amazon/lib/python2.7/site-packages/scipy/_lib/_numpy_compat.py:10: DeprecationWarning: Importing from numpy.testing.nosetester is deprecated, import from numpy.testing instead.
#   from numpy.testing.nosetester import import_nose
# /opt/amazon/lib/python2.7/site-packages/scipy/stats/morestats.py:12: DeprecationWarning: Importing from numpy.testing.decorators is deprecated, import from numpy.testing instead.
#   from numpy.testing.decorators import setastest
# [03/15/2020 17:29:37 INFO 140124243793728] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'_ftp_port': 8999, u'num_samples_per_tree': 256, u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'_log_level': u'info', u'_kvstore': u'dist_async', u'force_dense': u'true', u'epochs': 1, u'num_trees': 100, u'eval_metrics': [u'accuracy', u'precision_recall_fscore'], u'_num_kv_servers': u'auto', u'mini_batch_size': 1000}
# [03/15/2020 17:29:37 INFO 140124243793728] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'mini_batch_size': u'1000', u'feature_dim': u'48', u'num_samples_per_tree': u'512', u'num_trees': u'50'}
# [03/15/2020 17:29:37 INFO 140124243793728] Final configuration: {u'_ftp_port': 8999, u'num_samples_per_tree': u'512', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'_log_level': u'info', u'_kvstore': u'dist_async', u'force_dense': u'true', u'epochs': 1, u'feature_dim': u'48', u'num_trees': u'50', u'eval_metrics': [u'accuracy', u'precision_recall_fscore'], u'_num_kv_servers': u'auto', u'mini_batch_size': u'1000'}
# [03/15/2020 17:29:37 WARNING 140124243793728] Loggers have already been setup.
# [03/15/2020 17:29:38 INFO 140124243793728] Launching parameter server for role scheduler
# [03/15/2020 17:29:38 INFO 140124243793728] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/2761c695-8601-4ec8-94e0-3d292846399f', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-2', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'randomcutforest-2020-03-15-17-26-44-028', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-213-20.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/ea930700-9d38-4291-bd5b-be1873f6d0f4', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:066301190734:training-job/randomcutforest-2020-03-15-17-26-44-028', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [03/15/2020 17:29:38 INFO 140124243793728] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/2761c695-8601-4ec8-94e0-3d292846399f', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.213.20', 'AWS_REGION': 'us-east-2', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'randomcutforest-2020-03-15-17-26-44-028', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-213-20.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/ea930700-9d38-4291-bd5b-be1873f6d0f4', 'DMLC_ROLE': 'scheduler', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:066301190734:training-job/randomcutforest-2020-03-15-17-26-44-028', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [03/15/2020 17:29:38 INFO 140124243793728] Launching parameter server for role server
# [03/15/2020 17:29:38 INFO 140124243793728] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/2761c695-8601-4ec8-94e0-3d292846399f', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-2', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'randomcutforest-2020-03-15-17-26-44-028', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-213-20.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/ea930700-9d38-4291-bd5b-be1873f6d0f4', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:066301190734:training-job/randomcutforest-2020-03-15-17-26-44-028', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [03/15/2020 17:29:38 INFO 140124243793728] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/2761c695-8601-4ec8-94e0-3d292846399f', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.213.20', 'AWS_REGION': 'us-east-2', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'randomcutforest-2020-03-15-17-26-44-028', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-213-20.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/ea930700-9d38-4291-bd5b-be1873f6d0f4', 'DMLC_ROLE': 'server', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:066301190734:training-job/randomcutforest-2020-03-15-17-26-44-028', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [03/15/2020 17:29:38 INFO 140124243793728] Environment: {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/2761c695-8601-4ec8-94e0-3d292846399f', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '1', 'SAGEMAKER_HTTP_PORT': '8080', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.213.20', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'randomcutforest-2020-03-15-17-26-44-028', 'HOME': '/root', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-213-20.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/ea930700-9d38-4291-bd5b-be1873f6d0f4', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:066301190734:training-job/randomcutforest-2020-03-15-17-26-44-028', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# Process 31 is a shell:scheduler.
# Process 32 is a shell:server.
# Process 1 is a worker.
# [03/15/2020 17:29:38 INFO 140124243793728] Using default worker.
# [03/15/2020 17:29:38 INFO 140124243793728] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [03/15/2020 17:29:38 INFO 140124243793728] Verifying hyperparamemters...
# [03/15/2020 17:29:38 INFO 140124243793728] Hyperparameters are correct.
# [03/15/2020 17:29:38 INFO 140124243793728] Validating that feature_dim agrees with dimensions in training data...
# [03/15/2020 17:29:38 INFO 140124243793728] feature_dim is correct.
# [03/15/2020 17:29:38 INFO 140124243793728] Validating memory limits...
# [03/15/2020 17:29:38 INFO 140124243793728] Available memory in bytes: 15296843776
# [03/15/2020 17:29:38 INFO 140124243793728] Estimated sample size in bytes: 19660800
# [03/15/2020 17:29:38 INFO 140124243793728] Estimated memory needed to build the forest in bytes: 49152000
# [03/15/2020 17:29:38 INFO 140124243793728] Memory limits validated.
# [03/15/2020 17:29:38 INFO 140124243793728] Starting cluster sharing facilities...
# [03/15/2020 17:29:38 INFO 140124243793728] Create Store: dist_async
# [I 20-03-15 17:29:38] >>> starting FTP server on 0.0.0.0:8999, pid=1 <<<
# [03/15/2020 17:29:38 INFO 140122762766080] >>> starting FTP server on 0.0.0.0:8999, pid=1 <<<
# [I 20-03-15 17:29:38] poller: <class 'pyftpdlib.ioloop.Epoll'>
# [03/15/2020 17:29:38 INFO 140122762766080] poller: <class 'pyftpdlib.ioloop.Epoll'>
# [I 20-03-15 17:29:38] masquerade (NAT) address: None
# [03/15/2020 17:29:38 INFO 140122762766080] masquerade (NAT) address: None
# [I 20-03-15 17:29:38] passive ports: None
# [03/15/2020 17:29:38 INFO 140122762766080] passive ports: None
# [I 20-03-15 17:29:38] use sendfile(2): False
# [03/15/2020 17:29:38 INFO 140122762766080] use sendfile(2): False
# [03/15/2020 17:29:39 INFO 140124243793728] Cluster sharing facilities started.
# [03/15/2020 17:29:39 INFO 140124243793728] Verifying all workers are accessible...
# [03/15/2020 17:29:39 INFO 140124243793728] All workers accessible.
# [03/15/2020 17:29:39 INFO 140124243793728] Initializing Sampler...
# [03/15/2020 17:29:39 INFO 140124243793728] Sampler correctly initialized.
# #metrics {"Metrics": {"initialize.time": {"count": 1, "max": 670.1488494873047, "sum": 670.1488494873047, "min": 670.1488494873047}}, "EndTime": 1584293379.49334, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "RandomCutForest"}, "StartTime": 1584293378.817285}
#
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1584293379.493841, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "RandomCutForest"}, "StartTime": 1584293379.493781}
#
# [2020-03-15 17:29:39.494] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 674, "num_examples": 1, "num_bytes": 186224}
# [03/15/2020 17:29:39 INFO 140124243793728] Sampling training data...
# [2020-03-15 17:29:39.508] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 13, "num_examples": 1, "num_bytes": 186224}
# [03/15/2020 17:29:39 INFO 140124243793728] Sampling training data completed.
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "update.time": {"count": 1, "max": 17.297983169555664, "sum": 17.297983169555664, "min": 17.297983169555664}}, "EndTime": 1584293379.511448, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "RandomCutForest"}, "StartTime": 1584293379.493715}
#
# [03/15/2020 17:29:39 INFO 140124243793728] Early stop condition met. Stopping training.
# [03/15/2020 17:29:39 INFO 140124243793728] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 452, "sum": 452.0, "min": 452}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 452, "sum": 452.0, "min": 452}, "Max Records Seen Between Resets": {"count": 1, "max": 452, "sum": 452.0, "min": 452}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1584293379.51181, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "RandomCutForest", "epoch": 0}, "StartTime": 1584293379.494121}
#
# [03/15/2020 17:29:39 INFO 140124243793728] #throughput_metric: host=algo-1, train throughput=25351.6990679 records/second
# [03/15/2020 17:29:39 INFO 140124243793728] Master node: building Random Cut Forest...
# [03/15/2020 17:29:39 INFO 140124243793728] Gathering samples...
# [03/15/2020 17:29:39 INFO 140124243793728] 452 samples gathered
# [03/15/2020 17:29:39 INFO 140124243793728] Building Random Cut Forest...
# [03/15/2020 17:29:39 INFO 140124243793728] Random Cut Forest built:
#
# ForestInfo{num_trees: 50, num_samples_in_forest: 450, num_samples_per_tree: 9, sample_dim: 48, shingle_size: 1, trees_num_nodes: [17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 13, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, ], trees_depth: [7, 7, 5, 5, 6, 6, 5, 5, 8, 6, 6, 7, 5, 5, 6, 5, 7, 6, 6, 7, 7, 5, 6, 6, 6, 6, 5, 6, 5, 6, 5, 6, 5, 7, 6, 6, 5, 5, 7, 6, 6, 5, 8, 6, 6, 6, 5, 7, 6, 5, ], max_num_nodes: 17, min_num_nodes: 13, avg_num_nodes: 16, max_tree_depth: 8, min_tree_depth: 5, avg_tree_depth: 5, mem_size: 724624}
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 3.390073776245117, "sum": 3.390073776245117, "min": 3.390073776245117}, "model.bytes": {"count": 1, "max": 724624, "sum": 724624.0, "min": 724624}, "fit_model.time": {"count": 1, "max": 1.8260478973388672, "sum": 1.8260478973388672, "min": 1.8260478973388672}}, "EndTime": 1584293379.5155, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "RandomCutForest"}, "StartTime": 1584293379.511528}
#
# [03/15/2020 17:29:39 INFO 140124243793728] Master node: Serializing the RandomCutForest model
# #metrics {"Metrics": {"serialize_model.time": {"count": 1, "max": 27.666091918945312, "sum": 27.666091918945312, "min": 27.666091918945312}}, "EndTime": 1584293379.543306, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "RandomCutForest"}, "StartTime": 1584293379.515593}
#
# [03/15/2020 17:29:39 INFO 140124243793728] Test data is not provided.
# [I 20-03-15 17:29:39] >>> shutting down FTP server (0 active fds) <<<
# [03/15/2020 17:29:39 INFO 140122762766080] >>> shutting down FTP server (0 active fds) <<<
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 2163.794994354248, "sum": 2163.794994354248, "min": 2163.794994354248}, "setuptime": {"count": 1, "max": 1315.871000289917, "sum": 1315.871000289917, "min": 1315.871000289917}}, "EndTime": 1584293379.644388, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "RandomCutForest"}, "StartTime": 1584293379.543368}
#
#
# 2020-03-15 17:29:46 Uploading - Uploading generated training model
# 2020-03-15 17:29:46 Completed - Training job completed
# Training seconds: 67
# Billable seconds: 67

# %%
rcf_inference = rcf.deploy(
    initial_instance_count=1,
    instance_type='ml.m4.xlarge',
)

rcf_inference.content_type = 'text/csv'
rcf_inference.serializer = csv_serializer
rcf_inference.accept = 'appliation/json'
rcf_inference.deserializer = json_deserializer
# Out:
# -----------!

# %%
# Score the shingled datapoints
results = rcf_inference.predict(fake_data_shingled)
scores = np.array([datum['score'] for datum in results['scores']])

# compute the shingled score distribution and cutoff and determine anomalous scores
score_mean = scores.mean()
score_std = scores.std()
score_cutoff = score_mean + 1.8*score_std
print('score mean =', score_mean, ' score_cutoff =', score_cutoff)
anomalies = scores[scores > score_cutoff]
anomaly_indices = np.arange(len(scores))[scores > score_cutoff]

print(anomalies)
# Out:
# []

# %%
print('score mean =', score_mean, ' score_cutoff =', score_cutoff)
# Out:
# score mean = 1.6977799709119998  score_cutoff = 1.7412774211227386

# %%
len(fake_data_shingled[:,1])
fake_window = fake_data_shingled[:,1]

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

#
# *Try this out* - change `start` and `end` to zoom in on the 
# anomaly found earlier in this notebook
#
start, end = 0, len(fake_window)
fake_data_subset = fake_window[start:end]

ax1.plot(fake_window, color='C0', alpha=0.8)
ax2.plot(scores, color='C1')
ax2.scatter(anomaly_indices, anomalies, color='k')

ax1.grid(which='major', axis='both')
ax1.set_ylabel('temerature', color='C0')
ax2.set_ylabel('Anomaly Score', color='C1')
ax1.tick_params('y', colors='C0')
ax2.tick_params('y', colors='C1')
ax1.set_ylim(2, 5)
ax2.set_ylim(min(scores), 1.4*max(scores))
fig.set_figwidth(10)

# %%
anoms= []
for base in range(50, 400):
    results = rcf_inference.predict(fake_data_shingled[base:base+25])
    scores = np.array([datum['score'] for datum in results['scores']])

    # compute the shingled score distribution and cutoff and determine anomalous scores
    score_mean = scores.mean()
    score_std = scores.std()
    score_cutoff = score_mean +1.8*score_std

    anomalies = scores[scores > score_cutoff]
    anomaly_indices = np.arange(len(scores))[scores > score_cutoff]

    #print(anomalies)
    #print(anomaly_indices+base+10)
    anoms.append(anomaly_indices+base)

# %%
xl = []
for x in anoms:
    xl = xl+x.tolist()
s = set(xl)
xl = list(s)
anomalies = []
for x in xl:
    anomalies.append(2.0)
xl.sort()

# %%
len(fake_data_shingled)
fake_window = fake_data_shingled[:, 0]

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
anomaly_indices = xl
#
# *Try this out* - change `start` and `end` to zoom in on the 
# anomaly found earlier in this notebook
#
start, end = 0, len(fake_window)
fake_data_subset = fake_window[start:end]

ax1.plot(fake_window, color='C0', alpha=0.8)
#ax2.plot(scores, color='C1')
ax2.scatter(anomaly_indices, anomalies, color='k')

ax1.grid(which='major', axis='both')
#ax1.set_ylabel('temerature', color='C0')
ax2.set_ylabel('Anomaly Score', color='C1')
ax1.tick_params('y', colors='C0')
ax2.tick_params('y', colors='C1')
ax1.set_ylim(2, 5)
ax2.set_ylim(min(scores), 1.4*max(scores))
fig.set_figwidth(10)

# %%
sagemaker.Session().delete_endpoint(rcf_inference.endpoint)
